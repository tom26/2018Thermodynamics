# %% [markdown]
# # 2018 Thermodynamics Assignment Model Solution
#
# ## 1. Antoine Equations
#
# I will solve this assignment using a Benzene/Toluene Mixture.
#
# From NIST:
#
# The Antoine Equation for the vapour pressure is:
#
# $$
# \log_{10} (P/\text{bar}) = A - \frac{B}{T+C}
# $$
#
# Where $P$ is in bar and $T$ is in Kelvin. For Toluene,
#
# $$A = 4.08245; \quad	B = 1346.382 \text{K}; \quad 	C = -53.508 \text{K} $$
#
# For Benzene
#
# $$A = 4.01814; \quad	B = 1203.835 \text{K}; \quad 	C = -53.226 \text{K} $$
#
# The shared temperature range is $303\text{K} \leq T \leq 343\text{K}$. $T_{avg}$ is then $323\text{K}$. We calculate $P_{avg}$ below, and plots are made for each species.

# %%
#Define Vapour Pressures
p_B(T) = 10.^(4.01814 - 1203.835./(T-53.226))          #Benzene, bar
p_T(T) = 10.^(4.08245 - 1346.382./(T-53.508))          #Toluene, bar

#Calculate Pavg
T_min = 303; T_max = 343; T_avg = mean([T_min,T_max])
P_avg = (p_B(T_avg)*p_T(T_avg))^0.5
println("P_avg is equal to ",P_avg, " bar")

#Plot partial pressures
using Plots
Plots.scalefontsizes()
Plots.scalefontsizes(1.25)
plot(linspace(T_min,T_max,100), T -> p_B(T), label="Benzene", color="black", linewidth = 2, linestyle = :solid, legend = :topleft, ylim = (0,0.8))
plot!(linspace(T_min,T_max,100), T -> p_T(T), label="Toluene", color="black", linewidth = 2, linestyle = :dash, xlabel="Temperature (K)", ylabel = "Vapor Pressure (bar)", title= "Vapour Pressure of Benzene and Toluene")
# Out:
# P_avg is equal to 0.2094611073815501 bar
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9500">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9500)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9501">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9500)" points="
# 52.4041,358.025 580.315,358.025 580.315,31.4961 52.4041,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9502">
#     <rect x="52" y="31" width="529" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   144.789,358.025 144.789,31.4961
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   276.766,358.025 276.766,31.4961
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   408.744,358.025 408.744,31.4961
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   540.722,358.025 540.722,31.4961
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,276.393 580.315,276.393
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,194.76 580.315,194.76
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,113.128 580.315,113.128
#   "/>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   144.789,358.025 144.789,353.127
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   276.766,358.025 276.766,353.127
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   408.744,358.025 408.744,353.127
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   540.722,358.025 540.722,353.127
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 60.3228,358.025
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,276.393 60.3228,276.393
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,194.76 60.3228,194.76
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,113.128 60.3228,113.128
#   "/>
# <polyline clip-path="url(#clip9500)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,31.4961 60.3228,31.4961
#   "/>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 144.789, 374.225)" x="144.789" y="374.225">310</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 276.766, 374.225)" x="276.766" y="374.225">320</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 408.744, 374.225)" x="408.744" y="374.225">330</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 540.722, 374.225)" x="540.722" y="374.225">340</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 363.525)" x="46.4041" y="363.525">0.0</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 281.893)" x="46.4041" y="281.893">0.2</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 200.26)" x="46.4041" y="200.26">0.4</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 118.628)" x="46.4041" y="118.628">0.6</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 36.9961)" x="46.4041" y="36.9961">0.8</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 316.36, 22.8)" x="316.36" y="22.8">Vapour Pressure of Benzene and Toluene</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 316.36, 397)" x="316.36" y="397">Temperature (K)</text>
# </g>
# <g clip-path="url(#clip9500)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(-90, 18, 194.76)" x="18" y="194.76">Vapor Pressure (bar)</text>
# </g>
# <polyline clip-path="url(#clip9502)" style="stroke:#000000; stroke-width:2; stroke-opacity:1; fill:none" points="
#   52.4041,293.567 57.7366,292.401 63.069,291.219 68.4014,290.018 73.7339,288.8 79.0663,287.565 84.3987,286.311 89.7312,285.039 95.0636,283.749 100.396,282.44
#   105.728,281.112 111.061,279.765 116.393,278.4 121.726,277.014 127.058,275.61 132.391,274.185 137.723,272.74 143.055,271.275 148.388,269.79 153.72,268.284
#   159.053,266.757 164.385,265.209 169.718,263.64 175.05,262.049 180.383,260.437 185.715,258.802 191.047,257.146 196.38,255.467 201.712,253.765 207.045,252.041
#   212.377,250.293 217.71,248.522 223.042,246.728 228.374,244.91 233.707,243.068 239.039,241.202 244.372,239.311 249.704,237.395 255.037,235.455 260.369,233.49
#   265.701,231.499 271.034,229.482 276.366,227.44 281.699,225.371 287.031,223.276 292.364,221.155 297.696,219.006 303.028,216.831 308.361,214.628 313.693,212.397
#   319.026,210.139 324.358,207.852 329.691,205.537 335.023,203.194 340.355,200.822 345.688,198.42 351.02,195.989 356.353,193.529 361.685,191.038 367.018,188.517
#   372.35,185.966 377.683,183.384 383.015,180.772 388.347,178.127 393.68,175.452 399.012,172.745 404.345

# %% [markdown]
# We will label Toluene as species "A" and Benzene as species "B".
#
# # 2. Isothermal VLE
#
# We will construct $x_B-y_B$ and $P-x_B-y_B$ plots for these species at $T_{avg} = 323 \text{K}$.
#
# ## Isothermal $x_B-y_B$ Plot
#
# For the $x_B-y_B$ plot, we simply need to know the mole fraction of $B$ in the vapour phase, given the mole fraction of $B$ in the liquid phase. Assuming Raultian behaviour, the vapor pressure of $A$ and $B$ in the vapour phase will be:
#
# $$
# p_A = (1-x_B) p_{vap, A}(T)
# $$
#
# $$
# p_B = x_B p_{vap, B}(T)
# $$
#
# and so
#
# $$
# y_B = \frac{p_B}{P} = \frac{p_B}{p_A + p_B} = \frac{x_B p_{vap, B}(T)}{ x_B p_{vap, B}(T) + (1-x_B) p_{vap, A}(T)}
# $$
#
# As we assume temperature is constant, we may calculate this directly:

# %%
plot(linspace(0,1,100), x_B -> (x_B*p_B(T_avg))/(x_B*p_B(T_avg) + (1-x_B)*p_T(T_avg)), legend = :topleft, label = "yB", linewidth = 2, color = "black")
plot!(linspace(0,1,100), x -> x, label = "y = x", linewidth = 2, color = "black", linestyle=:dash, title = "Isothermal x-y Plot", xlabel = "xB", ylabel = "yB")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9700">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9700)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9701">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9700)" points="
# 52.4041,358.025 580.315,358.025 580.315,31.4961 52.4041,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9702">
#     <rect x="52" y="31" width="529" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   157.986,358.025 157.986,31.4961
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   263.568,358.025 263.568,31.4961
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.151,358.025 369.151,31.4961
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.733,358.025 474.733,31.4961
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,292.719 580.315,292.719
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,227.413 580.315,227.413
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,162.108 580.315,162.108
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,96.8018 580.315,96.8018
#   "/>
# <polyline clip-path="url(#clip9702)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,353.127
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   157.986,358.025 157.986,353.127
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   263.568,358.025 263.568,353.127
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.151,358.025 369.151,353.127
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.733,358.025 474.733,353.127
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 60.3228,358.025
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,292.719 60.3228,292.719
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,227.413 60.3228,227.413
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,162.108 60.3228,162.108
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,96.8018 60.3228,96.8018
#   "/>
# <polyline clip-path="url(#clip9700)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,31.4961 60.3228,31.4961
#   "/>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 52.4041, 374.225)" x="52.4041" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 157.986, 374.225)" x="157.986" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 263.568, 374.225)" x="263.568" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 369.151, 374.225)" x="369.151" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 474.733, 374.225)" x="474.733" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 363.525)" x="46.4041" y="363.525">0.0</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 298.219)" x="46.4041" y="298.219">0.2</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 232.913)" x="46.4041" y="232.913">0.4</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 167.608)" x="46.4041" y="167.608">0.6</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 102.302)" x="46.4041" y="102.302">0.8</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 36.9961)" x="46.4041" y="36.9961">1.0</text>
# </g>
# <g clip-path="url(#clip9700)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 316.36, 22.8)" x="316.36" y="22.8">Isothermal x-y Plot</text>
# </g>
# <g clip-path="u

# %% [markdown]
# ## $P-x_B-y_B$ Plot
#
# For the $P-x_B-y_B$ plot, we specify a total pressure, $P = p_A + p_B$, and we calculate the corresponding liquid and vapour compositions. For the liquid composition,
#
# $$
# P = p_A + p_B = (1-x_B) p_{vap, A}(T) +  x_B p_{vap, B}(T)
# $$
#
# Solving for $x_B$ gives
#
# $$
# x_B = \frac{P-p_{vap,A}(T)}{p_{vap,B}(T) - p_{vap,A}(T)}
# $$
#
# And then once $x_B$ is known, we calculate $y_B$ as
#
# $$
# y_B = \frac{p_{B}}{P} = \frac{x_Bp_{vap,B}(T)}{P}
# $$

# %%
#Lets do this manually,
P = linspace(p_T(T_avg), p_B(T_avg),100)                               #Pressure Values, bar
x_B = (P - p_T(T_avg))/(p_B(T_avg) - p_T(T_avg))                       #x_B values
y_B = x_B*p_B(T_avg)./P                                                #y_B values

#Plots
plot(x_B,P,legend = :topleft, label = "Liquid Composition", linewidth = 2, color = "black")
plot!(y_B,P, label = "Vapour Composition", linewidth = 2, color = "black", linestyle = :dash, title = "Isothermal P-x-y Plot", xlabel = "Mole Fraction of B", ylabel="Pressure (bar)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip9900">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9900)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9901">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip9900)" points="
# 60.7674,358.025 580.315,358.025 580.315,31.4961 60.7674,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip9902">
#     <rect x="60" y="31" width="521" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,358.025 60.7674,31.4961
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   164.677,358.025 164.677,31.4961
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   268.586,358.025 268.586,31.4961
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   372.496,358.025 372.496,31.4961
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   476.405,358.025 476.405,31.4961
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,319.567 580.315,319.567
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,250.831 580.315,250.831
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,182.095 580.315,182.095
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,113.358 580.315,113.358
#   "/>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,44.6217 580.315,44.6217
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,358.025 60.7674,31.4961
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,358.025 60.7674,353.127
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   164.677,358.025 164.677,353.127
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   268.586,358.025 268.586,353.127
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   372.496,358.025 372.496,353.127
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   476.405,358.025 476.405,353.127
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,319.567 68.5606,319.567
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,250.831 68.5606,250.831
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,182.095 68.5606,182.095
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,113.358 68.5606,113.358
#   "/>
# <polyline clip-path="url(#clip9900)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,44.6217 68.5606,44.6217
#   "/>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 60.7674, 374.225)" x="60.7674" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 164.677, 374.225)" x="164.677" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 268.586, 374.225)" x="268.586" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 372.496, 374.225)" x="372.496" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 476.405, 374.225)" x="476.405" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 325.067)" x="54.7674" y="325.067">0.15</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 256.331)" x="54.7674" y="256.331">0.20</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 187.595)" x="54.7674" y="187.595">0.25</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 118.858)" x="54.7674" y="118.858">0.30</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 50.1217)" x="54.7674" y="50.1217">0.35</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 320.541, 22.8)" x="320.541" y="22.8">Isothermal P-x-y Plot</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 320.541, 397)" x="320.541" y="397">Mole Fraction of B</text>
# </g>
# <g clip-path="url(#clip9900)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(-90, 18, 194.76)" x="18" y="194.76">Pressure (bar)</text>
# </g>
# <polyline clip-path="url(#clip9902)" style="stroke:#000000; strok

# %% [markdown]
# # 3. Isobaric VLE
#
# We will construct $x_B-y_B$ and $T-x_B-y_B$ plots at constant pressure $p_{avg}$. We'll handle both plots in one this time.
#
# We start with the equation we derived when creating the $P-x_B-y_B$ plot above,
#
# $$
# x_B = \frac{P-p_{vap,A}(T)}{p_{vap,B}(T) - p_{vap,A}(T)}
# $$
#
# Now, rather than treating $T$ as constant and $P$ as variable, we treat $T$ as variable and $P$ as constant, and calculate how $x_B$ varies with $T$. We then substitute these values into the other equation derived when making the $P-x_B-y_B$ plot,
#
# $$
# y_B = \frac{p_{B}}{P} = \frac{x_Bp_{vap,B}(T)}{P}
# $$
#
# to calculate the vapour fractions. We may then use this data for $x_B, y_B$ and $T$ to make both plots.

# %%
T = linspace(T_min, T_max, 100)                                           #Temperature Values (this will more than cover the required range.)
x_B = (P_avg - p_T(T))./(p_B(T) - p_T(T))                                 #x_B values
y_B = x_B.*p_B(T)/P_avg                                                   #y_B values 

#Create Isobaric xB-yB Plot
plot(x_B,y_B,linewidth = 2, color = "black", label="yB")
plot!(x_B,x_B, xlim = (0,1), ylim = (0,1), linewidth = 2, color = "black", linestyle = :dash, label = "y = x", legend = :topleft, xlabel = "xB", ylabel = "yB", title="Isobaric x-y Plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0100">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0101">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0100)" points="
# 52.4041,358.025 580.315,358.025 580.315,31.4961 52.4041,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0102">
#     <rect x="52" y="31" width="529" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   157.986,358.025 157.986,31.4961
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   263.568,358.025 263.568,31.4961
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.151,358.025 369.151,31.4961
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.733,358.025 474.733,31.4961
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,292.719 580.315,292.719
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,227.413 580.315,227.413
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,162.108 580.315,162.108
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,96.8018 580.315,96.8018
#   "/>
# <polyline clip-path="url(#clip0102)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,353.127
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   157.986,358.025 157.986,353.127
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   263.568,358.025 263.568,353.127
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.151,358.025 369.151,353.127
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.733,358.025 474.733,353.127
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 60.3228,358.025
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,292.719 60.3228,292.719
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,227.413 60.3228,227.413
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,162.108 60.3228,162.108
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,96.8018 60.3228,96.8018
#   "/>
# <polyline clip-path="url(#clip0100)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,31.4961 60.3228,31.4961
#   "/>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 52.4041, 374.225)" x="52.4041" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 157.986, 374.225)" x="157.986" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 263.568, 374.225)" x="263.568" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 369.151, 374.225)" x="369.151" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 474.733, 374.225)" x="474.733" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 363.525)" x="46.4041" y="363.525">0.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 298.219)" x="46.4041" y="298.219">0.2</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 232.913)" x="46.4041" y="232.913">0.4</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 167.608)" x="46.4041" y="167.608">0.6</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 102.302)" x="46.4041" y="102.302">0.8</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 36.9961)" x="46.4041" y="36.9961">1.0</text>
# </g>
# <g clip-path="url(#clip0100)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 316.36, 22.8)" x="316.36" y="22.8">Isobaric x-y Plot</text>
# </g>
# <g clip-path="url

# %%
#Create T-x-y Plot
plot(x_B,T,linewidth = 2, color = "black", label="Liquid Composition")
plot!(y_B,T, xlim = (0,1), linewidth = 2, color = "black", linestyle = :dash, label = "Vapour Composition", legend = :topright, xlabel = "Mole Fraction of B", ylabel = "Temperature (K)", title="Isobaric T-x-y Plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip0300">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0300)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0301">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip0300)" points="
# 56.5858,358.025 580.315,358.025 580.315,31.4961 56.5858,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip0302">
#     <rect x="56" y="31" width="525" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.5858,358.025 56.5858,31.4961
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   161.332,358.025 161.332,31.4961
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   266.077,358.025 266.077,31.4961
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   370.823,358.025 370.823,31.4961
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   475.569,358.025 475.569,31.4961
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.5858,300.882 580.315,300.882
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.5858,219.25 580.315,219.25
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.5858,137.618 580.315,137.618
#   "/>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   56.5858,55.9857 580.315,55.9857
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.5858,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.5858,358.025 56.5858,31.4961
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.5858,358.025 56.5858,353.127
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   161.332,358.025 161.332,353.127
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   266.077,358.025 266.077,353.127
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   370.823,358.025 370.823,353.127
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   475.569,358.025 475.569,353.127
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.5858,300.882 64.4417,300.882
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.5858,219.25 64.4417,219.25
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.5858,137.618 64.4417,137.618
#   "/>
# <polyline clip-path="url(#clip0300)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   56.5858,55.9857 64.4417,55.9857
#   "/>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 56.5858, 374.225)" x="56.5858" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 161.332, 374.225)" x="161.332" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 266.077, 374.225)" x="266.077" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 370.823, 374.225)" x="370.823" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 475.569, 374.225)" x="475.569" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 50.5858, 306.382)" x="50.5858" y="306.382">310</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 50.5858, 224.75)" x="50.5858" y="224.75">320</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 50.5858, 143.118)" x="50.5858" y="143.118">330</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 50.5858, 61.4857)" x="50.5858" y="61.4857">340</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 318.45, 22.8)" x="318.45" y="22.8">Isobaric T-x-y Plot</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 318.45, 397)" x="318.45" y="397">Mole Fraction of B</text>
# </g>
# <g clip-path="url(#clip0300)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(-90, 18, 194.76)" x="18" y="194.76">Temperature (K)</text>
# </g>
# <polyline clip-path="url(#clip0302)" style="stroke:#000000; stroke-width:2; stroke-opacity:1; fill:none" points="
#   827.051,358.025 809.459,354.727 792.206,351.428 775.284,348.13 758.685,344.832 742.403,341.533 726.429,338.235 710.756,334.937 695.379,331.639 680.289,328.34
#   665.481,325.042 650.948,321.744 636.684,318.446 622.683,315.147 608.939,311.849 595.446,308.551 582.199,305.253 569.191,301.954 556.419,298.656 543.876,295.358
#   531.558,292.059 519.459,288.761 507.575,285.463 495.901,282.165 484.432,278.866 473.165,275.568 462.094,272.27 451.215,268.972 440.525,265.673 430.019,262.375
#   419.693,259.077 409.543,255.778 39
