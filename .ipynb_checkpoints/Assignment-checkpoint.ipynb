# %% [markdown]
# # 2018 Thermodynamics Assignment Model Solution
#
# ## 1. Antoine Equations
#
# I will solve this assignment using a Benzene/Ethanol Mixture.
#
# From NIST:
#
# The Antoine Equation for the vapour pressure is:
#
# $$
# \log_{10} (P/\text{bar}) = A - \frac{B}{T+C}
# $$
#
# Where $P$ is in bar and $T$ is in Kelvin. For Ethanol,
#
# $$A = 5.37229; \quad	B = 1670.409 \text{K}; \quad 	C = -40.191 \text{K} $$
#
# For Benzene
#
# $$A = 4.01814; \quad	B = 1203.835 \text{K}; \quad 	C = -53.226 \text{K} $$
#
# The shared temperature range is $287\text{K} \leq T \leq 351\text{K}$. $T_{avg}$ is then $319\text{K}$. We calculate $P_{avg}$ below, and plots are made for each species.

# %%
#Define Vapour Pressures
p_B(T) = 10.^(4.01814 - 1203.835./(T-53.226))           #Benzene, bar
p_E(T) = 10.^(5.37229 - 1670.409./(T-40.1918))          #Ethanol, bar

#Calculate Pavg
T_min = 287; T_max = 351; T_avg = mean([T_min,T_max])
P_avg = (p_B(T_avg)*p_E(T_avg))^0.5
println("P_avg is equal to ",P_avg, " bar")

#Plot partial pressures
using Plots
Plots.scalefontsizes()
Plots.scalefontsizes(1.25)
plot(linspace(T_min,T_max,100), T -> p_B(T), label="Benzene", color="black", linewidth = 2, linestyle = :solid, legend = :topleft, ylim = (0,0.8))
plot!(linspace(T_min,T_max,100), T -> p_E(T), label="Ethanol", color="black", linewidth = 2, linestyle = :dash, xlabel="Temperature (K)", ylabel = "Vapor Pressure (bar)", title= "Vapour Pressure of Benzene and Ethanol")
# Out:
# P_avg is equal to 0.27215679227675393 bar
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip5200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5200)" points="
# 52.4041,358.025 580.315,358.025 580.315,31.4961 52.4041,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5202">
#     <rect x="52" y="31" width="529" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   77.15,358.025 77.15,31.4961
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   159.636,358.025 159.636,31.4961
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   242.122,358.025 242.122,31.4961
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   324.608,358.025 324.608,31.4961
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   407.094,358.025 407.094,31.4961
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   489.58,358.025 489.58,31.4961
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   572.066,358.025 572.066,31.4961
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,276.393 580.315,276.393
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,194.76 580.315,194.76
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,113.128 580.315,113.128
#   "/>
# <polyline clip-path="url(#clip5202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   77.15,358.025 77.15,353.127
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   159.636,358.025 159.636,353.127
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   242.122,358.025 242.122,353.127
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   324.608,358.025 324.608,353.127
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   407.094,358.025 407.094,353.127
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   489.58,358.025 489.58,353.127
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   572.066,358.025 572.066,353.127
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 60.3228,358.025
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,276.393 60.3228,276.393
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,194.76 60.3228,194.76
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,113.128 60.3228,113.128
#   "/>
# <polyline clip-path="url(#clip5200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,31.4961 60.3228,31.4961
#   "/>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 77.15, 374.225)" x="77.15" y="374.225">290</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 159.636, 374.225)" x="159.636" y="374.225">300</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 242.122, 374.225)" x="242.122" y="374.225">310</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 324.608, 374.225)" x="324.608" y="374.225">320</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 407.094, 374.225)" x="407.094" y="374.225">330</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 489.58, 374.225)" x="489.58" y="374.225">340</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 572.066, 374.225)" x="572.066" y="374.225">350</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 363.525)" x="46.4041" y="363.525">0.0</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 281.893)" x="46.4041" y="281.893">0.2</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 200.26)" x="46.4041" y="200.26">0.4</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 118.628)" x="46.4041" y="118.628">0.6</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 36.9961)" x="46.4041" y="36.9961">0.8</text>
# </g>
# <g clip-path="url(#clip5200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 316.36, 22.8)" x="316.36" y="22.8">Vapour Pressure of Benzene and Ethanol</text>
# </g>
# <g clip-path="url

# %% [markdown]
# We will label Ethanol as species "A" and Benzene as species "B".
#
# # 2. Isothermal VLE
#
# We will construct $x_B-y_B$ and $P-x_B-y_B$ plots for these species at $T_{avg} = 323 \text{K}$.
#
# ## Isothermal $x_B-y_B$ Plot
#
# For the $x_B-y_B$ plot, we simply need to know the mole fraction of $B$ in the vapour phase, given the mole fraction of $B$ in the liquid phase. Assuming Raultian behaviour, the vapor pressure of $A$ and $B$ in the vapour phase will be:
#
# $$
# p_A = (1-x_B) p_{vap, A}(T)
# $$
#
# $$
# p_B = x_B p_{vap, B}(T)
# $$
#
# and so
#
# $$
# y_B = \frac{p_B}{P} = \frac{p_B}{p_A + p_B} = \frac{x_B p_{vap, B}(T)}{ x_B p_{vap, B}(T) + (1-x_B) p_{vap, A}(T)}
# $$
#
# As we assume temperature is constant, we may calculate this directly:

# %%
plot(linspace(0,1,100), x_B -> (x_B*p_B(T_avg))/(x_B*p_B(T_avg) + (1-x_B)*p_E(T_avg)), legend = :topleft, label = "yB", linewidth = 2, color = "black")
plot!(linspace(0,1,100), x -> x, label = "y = x", linewidth = 2, color = "black", linestyle=:dash, title = "Isothermal x-y Plot", xlabel = "xB", ylabel = "yB")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip5400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 52.4041,358.025 580.315,358.025 580.315,31.4961 52.4041,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5402">
#     <rect x="52" y="31" width="529" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   157.986,358.025 157.986,31.4961
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   263.568,358.025 263.568,31.4961
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.151,358.025 369.151,31.4961
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.733,358.025 474.733,31.4961
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,292.719 580.315,292.719
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,227.413 580.315,227.413
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,162.108 580.315,162.108
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,96.8018 580.315,96.8018
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,353.127
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   157.986,358.025 157.986,353.127
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   263.568,358.025 263.568,353.127
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.151,358.025 369.151,353.127
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.733,358.025 474.733,353.127
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 60.3228,358.025
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,292.719 60.3228,292.719
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,227.413 60.3228,227.413
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,162.108 60.3228,162.108
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,96.8018 60.3228,96.8018
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,31.4961 60.3228,31.4961
#   "/>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 52.4041, 374.225)" x="52.4041" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 157.986, 374.225)" x="157.986" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 263.568, 374.225)" x="263.568" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 369.151, 374.225)" x="369.151" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 474.733, 374.225)" x="474.733" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 363.525)" x="46.4041" y="363.525">0.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 298.219)" x="46.4041" y="298.219">0.2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 232.913)" x="46.4041" y="232.913">0.4</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 167.608)" x="46.4041" y="167.608">0.6</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 102.302)" x="46.4041" y="102.302">0.8</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 36.9961)" x="46.4041" y="36.9961">1.0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 316.36, 22.8)" x="316.36" y="22.8">Isothermal x-y Plot</text>
# </g>
# <g clip-path="u

# %% [markdown]
# ## $P-x_B-y_B$ Plot
#
# For the $P-x_B-y_B$ plot, we specify a total pressure, $P = p_A + p_B$, and we calculate the corresponding liquid and vapour compositions. For the liquid composition,
#
# $$
# P = p_A + p_B = (1-x_B) p_{vap, A}(T) +  x_B p_{vap, B}(T)
# $$
#
# Solving for $x_B$ gives
#
# $$
# x_B = \frac{P-p_{vap,A}(T)}{p_{vap,B}(T) - p_{vap,A}(T)}
# $$
#
# And then once $x_B$ is known, we calculate $y_B$ as
#
# $$
# y_B = \frac{p_{B}}{P} = \frac{x_Bp_{vap,B}(T)}{P}
# $$

# %%
#Lets do this manually,
P = linspace(p_E(T_avg), p_B(T_avg),100)                               #Pressure Values, bar
x_B = (P - p_E(T_avg))/(p_B(T_avg) - p_E(T_avg))                       #x_B values
y_B = x_B*p_B(T_avg)./P                                                #y_B values

#Plots
plot(x_B,P,legend = :topleft, label = "Liquid Composition", linewidth = 2, color = "black")
plot!(y_B,P, label = "Vapour Composition", linewidth = 2, color = "black", linestyle = :dash, title = "Isothermal P-x-y Plot", xlabel = "Mole Fraction of B", ylabel="Pressure (bar)")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip5600">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5601">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5600)" points="
# 60.7674,358.025 580.315,358.025 580.315,31.4961 60.7674,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5602">
#     <rect x="60" y="31" width="521" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,358.025 60.7674,31.4961
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   164.677,358.025 164.677,31.4961
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   268.586,358.025 268.586,31.4961
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   372.496,358.025 372.496,31.4961
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   476.405,358.025 476.405,31.4961
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,311.923 580.315,311.923
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,263.601 580.315,263.601
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,215.278 580.315,215.278
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,166.955 580.315,166.955
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,118.633 580.315,118.633
#   "/>
# <polyline clip-path="url(#clip5602)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   60.7674,70.3098 580.315,70.3098
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,358.025 60.7674,31.4961
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,358.025 60.7674,353.127
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   164.677,358.025 164.677,353.127
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   268.586,358.025 268.586,353.127
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   372.496,358.025 372.496,353.127
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   476.405,358.025 476.405,353.127
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,311.923 68.5606,311.923
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,263.601 68.5606,263.601
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,215.278 68.5606,215.278
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,166.955 68.5606,166.955
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,118.633 68.5606,118.633
#   "/>
# <polyline clip-path="url(#clip5600)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   60.7674,70.3098 68.5606,70.3098
#   "/>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 60.7674, 374.225)" x="60.7674" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 164.677, 374.225)" x="164.677" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 268.586, 374.225)" x="268.586" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 372.496, 374.225)" x="372.496" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 476.405, 374.225)" x="476.405" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 317.423)" x="54.7674" y="317.423">0.25</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 269.101)" x="54.7674" y="269.101">0.26</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 220.778)" x="54.7674" y="220.778">0.27</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 172.455)" x="54.7674" y="172.455">0.28</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 124.133)" x="54.7674" y="124.133">0.29</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 54.7674, 75.8098)" x="54.7674" y="75.8098">0.30</text>
# </g>
# <g clip-path="url(#clip5600)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 320.541, 22.8)" x="320.541" y="22.8">Isothermal P-x-y Plot</text>
# </g>
# <g cl

# %% [markdown]
# # 3. Isobaric VLE
#
# We will construct $x_B-y_B$ and $T-x_B-y_B$ plots at constant pressure $p_{avg}$. We'll handle both plots in one this time.
#
# We start with the equation we derived when creating the $P-x_B-y_B$ plot above,
#
# $$
# x_B = \frac{P-p_{vap,A}(T)}{p_{vap,B}(T) - p_{vap,A}(T)}
# $$
#
# Now, rather than treating $T$ as constant and $P$ as variable, we treat $T$ as variable and $P$ as constant, and calculate how $x_B$ varies with $T$. We then substitute these values into the other equation derived when making the $P-x_B-y_B$ plot,
#
# $$
# y_B = \frac{p_{B}}{P} = \frac{x_Bp_{vap,B}(T)}{P}
# $$
#
# to calculate the vapour fractions. We may then use this data for $x_B, y_B$ and $T$ to make both plots.

# %%
T = linspace(315, 325, 100)                                               #Temperature Values (this will more than cover the required range.)
x_B = (P_avg - p_E(T))./(p_B(T) - p_E(T))                                 #x_B values
y_B = x_B.*p_B(T)/P_avg                                                   #y_B values 

#Create Isobaric xB-yB Plot
plot(x_B,y_B,linewidth = 2, color = "black", label="yB")
plot!(x_B,x_B, xlim = (0,1), ylim = (0,1), linewidth = 2, color = "black", linestyle = :dash, label = "y = x", legend = :topleft, xlabel = "xB", ylabel = "yB", title="Isobaric x-y Plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1200)" points="
# 52.4041,358.025 580.315,358.025 580.315,31.4961 52.4041,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1202">
#     <rect x="52" y="31" width="529" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   157.986,358.025 157.986,31.4961
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   263.568,358.025 263.568,31.4961
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.151,358.025 369.151,31.4961
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.733,358.025 474.733,31.4961
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,292.719 580.315,292.719
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,227.413 580.315,227.413
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,162.108 580.315,162.108
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,96.8018 580.315,96.8018
#   "/>
# <polyline clip-path="url(#clip1202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,353.127
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   157.986,358.025 157.986,353.127
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   263.568,358.025 263.568,353.127
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.151,358.025 369.151,353.127
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.733,358.025 474.733,353.127
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 60.3228,358.025
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,292.719 60.3228,292.719
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,227.413 60.3228,227.413
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,162.108 60.3228,162.108
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,96.8018 60.3228,96.8018
#   "/>
# <polyline clip-path="url(#clip1200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,31.4961 60.3228,31.4961
#   "/>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 52.4041, 374.225)" x="52.4041" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 157.986, 374.225)" x="157.986" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 263.568, 374.225)" x="263.568" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 369.151, 374.225)" x="369.151" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 474.733, 374.225)" x="474.733" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 363.525)" x="46.4041" y="363.525">0.0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 298.219)" x="46.4041" y="298.219">0.2</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 232.913)" x="46.4041" y="232.913">0.4</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 167.608)" x="46.4041" y="167.608">0.6</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 102.302)" x="46.4041" y="102.302">0.8</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 36.9961)" x="46.4041" y="36.9961">1.0</text>
# </g>
# <g clip-path="url(#clip1200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 316.36, 22.8)" x="316.36" y="22.8">Isobaric x-y Plot</text>
# </g>
# <g clip-path="url

# %%
#Create T-x-y Plot
plot(x_B,T,linewidth = 2, color = "black", label="Liquid Composition")
plot!(y_B,T, xlim = (0,1), linewidth = 2, color = "black", linestyle = :dash, label = "Vapour Composition", legend = :topright, xlabel = "Mole Fraction of B", ylabel = "Temperature (K)", title="Isobaric T-x-y Plot")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip1400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip1400)" points="
# 69.1306,358.025 580.315,358.025 580.315,31.4961 69.1306,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip1402">
#     <rect x="69" y="31" width="512" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   69.1306,358.025 69.1306,31.4961
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   171.367,358.025 171.367,31.4961
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   273.604,358.025 273.604,31.4961
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   375.841,358.025 375.841,31.4961
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   478.078,358.025 478.078,31.4961
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   69.1306,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   69.1306,276.393 580.315,276.393
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   69.1306,194.76 580.315,194.76
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   69.1306,113.128 580.315,113.128
#   "/>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   69.1306,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,358.025 69.1306,31.4961
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,358.025 69.1306,353.127
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   171.367,358.025 171.367,353.127
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   273.604,358.025 273.604,353.127
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   375.841,358.025 375.841,353.127
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   478.078,358.025 478.078,353.127
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,358.025 76.7984,358.025
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,276.393 76.7984,276.393
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,194.76 76.7984,194.76
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,113.128 76.7984,113.128
#   "/>
# <polyline clip-path="url(#clip1400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   69.1306,31.4961 76.7984,31.4961
#   "/>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 69.1306, 374.225)" x="69.1306" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 171.367, 374.225)" x="171.367" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 273.604, 374.225)" x="273.604" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 375.841, 374.225)" x="375.841" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 478.078, 374.225)" x="478.078" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 63.1306, 363.525)" x="63.1306" y="363.525">315.0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 63.1306, 281.893)" x="63.1306" y="281.893">317.5</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 63.1306, 200.26)" x="63.1306" y="200.26">320.0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 63.1306, 118.628)" x="63.1306" y="118.628">322.5</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 63.1306, 36.9961)" x="63.1306" y="36.9961">325.0</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 324.723, 22.8)" x="324.723" y="22.8">Isobaric T-x-y Plot</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(0, 324.723, 397)" x="324.723" y="397">Mole Fraction of B</text>
# </g>
# <g clip-path="url(#clip1400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:21; text-anchor:middle;" transform="rotate(-90, 18, 194.76)" x="18" y="194.76">Temperature (K)</text>
# </g>
# <polyline clip-path="url(#clip1402)" style="stroke:#000000; stroke-

# %% [markdown]
# #  4. Non-Ideality.
#
# To account for non-ideality, we either need experimental data or an activity coefficient model. Activity coefficient data may be found in many places - the simplest is probably ASPEN. However, for this common system, Margules activity coefficient data is provided by Perry's Handbook. We have
#
#
# $$
# \ln \gamma_A  = [A_{12} + 2(A_{21}-A_{12})x_A]x_B^2
# $$
#
#
# $$
# \ln \gamma_B  = [A_{21} + 2(A_{12}-A_{21})x_B]x_A^2
# $$
#
# And for this system, $A_{12} = 1.8362$, and $A_{21} = 1.4717$; we will ignore the temperature dependence of these activity coefficients over the range of values considered. Plotting the activity coefficients:

# %%
A_12 = 1.8362; A_21 = 1.4717;

γ_A(xB) = exp((A_12 + 2(A_21 - A_12)*(1-xB))*xB^2)
γ_B(xB) = exp((A_21 + 2(A_12 - A_21)*xB)*(1-xB)^2)

plot(linspace(0,1,100), xB -> γ_A(xB),color="black", linewidth=2,label="Ethanol")
plot!(linspace(0,1,100), xB -> γ_B(xB),color="black", linewidth=2,linestyle = :dash, label = "Benzene", legend = :top, xlabel = "Mole Fraction of Benzene", ylabel = "Activity Coefficient", title="Activity Coefficients")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip2400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip2400)" points="
# 39.8593,358.025 580.315,358.025 580.315,31.4961 39.8593,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip2402">
#     <rect x="39" y="31" width="541" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.8593,358.025 39.8593,31.4961
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   147.95,358.025 147.95,31.4961
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   256.042,358.025 256.042,31.4961
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   364.133,358.025 364.133,31.4961
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   472.224,358.025 472.224,31.4961
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.8593,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.8593,296.096 580.315,296.096
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.8593,234.167 580.315,234.167
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.8593,172.239 580.315,172.239
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.8593,110.31 580.315,110.31
#   "/>
# <polyline clip-path="url(#clip2402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   39.8593,48.3813 580.315,48.3813
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,358.025 39.8593,31.4961
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,358.025 39.8593,353.127
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   147.95,358.025 147.95,353.127
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   256.042,358.025 256.042,353.127
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   364.133,358.025 364.133,353.127
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   472.224,358.025 472.224,353.127
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,358.025 47.9661,358.025
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,296.096 47.9661,296.096
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,234.167 47.9661,234.167
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,172.239 47.9661,172.239
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,110.31 47.9661,110.31
#   "/>
# <polyline clip-path="url(#clip2400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   39.8593,48.3813 47.9661,48.3813
#   "/>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 39.8593, 374.225)" x="39.8593" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 147.95, 374.225)" x="147.95" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 256.042, 374.225)" x="256.042" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 364.133, 374.225)" x="364.133" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 472.224, 374.225)" x="472.224" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 33.8593, 363.525)" x="33.8593" y="363.525">1</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 33.8593, 301.596)" x="33.8593" y="301.596">2</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 33.8593, 239.667)" x="33.8593" y="239.667">3</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 33.8593, 177.739)" x="33.8593" y="177.739">4</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 33.8593, 115.81)" x="33.8593" y="115.81">5</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 33.8593, 53.8813)" x="33.8593" y="53.8813">6</text>
# </g>
# <g clip-path="url(#clip2400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 310.087, 22.8)" x="310.087" y="22.8">Activity Coefficients</text>
# </g>
# <g clip-path="url(#clip2400)">
# <tex

# %% [markdown]
# We clearly have *strongly* non-ideal behaviour, and in particular we have a positive deviation: the ethanol and benzene don't want to be together in solution. This is reasonable, as the ethanol has a polar alcohol group, while Benzene is very non-polar. We can now recalculate the isothermal $x-y$ and $P-x-y$ plots using these activity coefficients. For the $x-y$ plot, instead of the equation used above:
#
# $$
# y_B = \frac{p_B}{P} = \frac{p_B}{p_A + p_B} = \frac{x_B p_{vap, B}(T)}{ x_B p_{vap, B}(T) + (1-x_B) p_{vap, A}(T)}
# $$
#
# we now have
#
# $$
# y_B = \frac{p_B}{P} = \frac{p_B}{p_A + p_B} = \frac{\gamma_Bx_B p_{vap, B}(T)}{ \gamma_Bx_B p_{vap, B}(T) + \gamma_A(1-x_B) p_{vap, A}(T)}
# $$

# %%
plot(linspace(0,1,100), x_B -> (x_B*p_B(T_avg))/(x_B*p_B(T_avg) + (1-x_B)*p_E(T_avg)), legend = :topleft, label = "yB Ideal", linewidth = 2, color = "black")
plot!(linspace(0,1,100), x_B -> (γ_B(x_B)*x_B*p_B(T_avg))/(γ_B(x_B)*x_B*p_B(T_avg) + γ_A(x_B)*(1-x_B)*p_E(T_avg)), label = "yB Non-Ideal", linewidth = 2, color = "black", linestyle=:dash)
plot!(linspace(0,1,100), x -> x, label = "y = x", linewidth = 2, color = "black", linestyle=:dot, title = "Isothermal x-y Plot", xlabel = "xB", ylabel = "yB")
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip3200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip3200)" points="
# 52.4041,358.025 580.315,358.025 580.315,31.4961 52.4041,31.4961
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip3202">
#     <rect x="52" y="31" width="529" height="328"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   157.986,358.025 157.986,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   263.568,358.025 263.568,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   369.151,358.025 369.151,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   474.733,358.025 474.733,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   580.315,358.025 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,292.719 580.315,292.719
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,227.413 580.315,227.413
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,162.108 580.315,162.108
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,96.8018 580.315,96.8018
#   "/>
# <polyline clip-path="url(#clip3202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   52.4041,31.4961 580.315,31.4961
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 580.315,358.025
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,31.4961
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 52.4041,353.127
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   157.986,358.025 157.986,353.127
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   263.568,358.025 263.568,353.127
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   369.151,358.025 369.151,353.127
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   474.733,358.025 474.733,353.127
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   580.315,358.025 580.315,353.127
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,358.025 60.3228,358.025
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,292.719 60.3228,292.719
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,227.413 60.3228,227.413
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,162.108 60.3228,162.108
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,96.8018 60.3228,96.8018
#   "/>
# <polyline clip-path="url(#clip3200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   52.4041,31.4961 60.3228,31.4961
#   "/>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 52.4041, 374.225)" x="52.4041" y="374.225">0.0</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 157.986, 374.225)" x="157.986" y="374.225">0.2</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 263.568, 374.225)" x="263.568" y="374.225">0.4</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 369.151, 374.225)" x="369.151" y="374.225">0.6</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 474.733, 374.225)" x="474.733" y="374.225">0.8</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:middle;" transform="rotate(0, 580.315, 374.225)" x="580.315" y="374.225">1.0</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 363.525)" x="46.4041" y="363.525">0.0</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 298.219)" x="46.4041" y="298.219">0.2</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 232.913)" x="46.4041" y="232.913">0.4</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 167.608)" x="46.4041" y="167.608">0.6</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 102.302)" x="46.4041" y="102.302">0.8</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:15; text-anchor:end;" transform="rotate(0, 46.4041, 36.9961)" x="46.4041" y="36.9961">1.0</text>
# </g>
# <g clip-path="url(#clip3200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:26; text-anchor:middle;" transform="rotate(0, 316.36, 22.8)" x="316.36" y="22.8">Isothermal x-y Plot</text>
# </g>
# <g clip-path="u

# %% [markdown]
# It seems Raoult's law may be, umm... problematic. Based solely on the relative vapour pressures (which are similar), Raoult's law predicts the vapour and liquid compositions should be quite similar. However, when non-ideal mixing is accounted for, we see this is far from the truth. For low concentrations of benzene, the benzene would much rather be in the gas phase, and ethanol is much happier condensed as a liquid with other ethanol molecules. However, at higher benzene composition, the opposite occurs - benzene is happier in the liquid, and ethanol in the gas phase. In the middle we have an *azeotrope*, where both the liquid and the gas have equal composition (around $x_B = y_B = 0.6$). This azeotrope will make traditional separations much more difficult, and we will need to consider various methods of azeotropic distillation to 'break' the azeotrope.
